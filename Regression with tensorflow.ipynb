# %% [markdown]
# # Regression Project with TensorFlow
#
# California Housing Data
#
# This data set contains information about all the block groups in California from the 1990 Census. In this sample a block group on average includes 1425.5 individuals living in a geographically compact area.
#
# The task is to aproximate the median house value of each block from the values of the rest of the variables.
#
#  It has been obtained from the LIACC repository. The original page where the data set can be found is: http://www.liaad.up.pt/~ltorgo/Regression/DataSets.html.

# %% [markdown]
# The Features:
#
# * housingMedianAge: continuous.
# * totalRooms: continuous.
# * totalBedrooms: continuous.
# * population: continuous.
# * households: continuous.
# * medianIncome: continuous.
# * medianHouseValue: continuous.

# %% [markdown]
# ## The Data

# %% [markdown]
# ** Import the cal_housing_clean.csv file with pandas. Separate it into a training (70%) and testing set(30%).**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data=pd.read_csv("cal_housing_clean.csv")

# %%
data.head()
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0              41.0       880.0          129.0       322.0       126.0
# 1              21.0      7099.0         1106.0      2401.0      1138.0
# 2              52.0      1467.0          190.0       496.0       177.0
# 3              52.0      1274.0          235.0       558.0       219.0
# 4              52.0      1627.0          280.0       565.0       259.0
#
#    medianIncome  medianHouseValue
# 0        8.3252          452600.0
# 1        8.3014          358500.0
# 2        7.2574          352100.0
# 3        5.6431          341300.0
# 4        3.8462          342200.0

# %%
data.describe()
# Out:
#        housingMedianAge    totalRooms  totalBedrooms    population  \
# count      20640.000000  20640.000000   20640.000000  20640.000000
# mean          28.639486   2635.763081     537.898014   1425.476744
# std           12.585558   2181.615252     421.247906   1132.462122
# min            1.000000      2.000000       1.000000      3.000000
# 25%           18.000000   1447.750000     295.000000    787.000000
# 50%           29.000000   2127.000000     435.000000   1166.000000
# 75%           37.000000   3148.000000     647.000000   1725.000000
# max           52.000000  39320.000000    6445.000000  35682.000000
#
#          households  medianIncome  medianHouseValue
# count  20640.000000  20640.000000      20640.000000
# mean     499.539680      3.870671     206855.816909
# std      382.329753      1.899822     115395.615874
# min        1.000000      0.499900      14999.000000
# 25%      280.000000      2.563400     119600.000000
# ...

# %%
x_data=data.drop('medianHouseValue', axis=1)
y_label=data['medianHouseValue']

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_label, test_size=0.30, random_state=101)

# %%
data.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
cols=['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
       'households', 'medianIncome',]

# %% [markdown]
# ### Scale the Feature Data
#
# ** Use sklearn preprocessing to create a MinMaxScaler for the feature data. Fit this scaler only to the training data. Then use it to transform X_test and X_train. Then use the scaled X_test and X_train along with pd.Dataframe to re-create two dataframes of scaled data.**

# %%
sacler=MinMaxScaler()

# %%
xtrain=sacler.fit_transform(X_train)
xtest=sacler.fit_transform(X_test)

# %%
x_train_df=pd.DataFrame(xtrain_df,columns=cols)
y_test_df=pd.DataFrame(xtest_df,columns=cols)

# %%
x_train_df.head()
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0          0.352941    0.069688       0.117163    0.048769    0.115442
# 1          0.607843    0.011242       0.015673    0.008367    0.014142
# 2          0.666667    0.025230       0.031347    0.020971    0.030258
# 3          0.666667    0.032530       0.033830    0.024752    0.030094
# 4          0.294118    0.031919       0.035692    0.019466    0.034863
#
#    medianIncome
# 0      0.142508
# 1      0.045027
# 2      0.212866
# 3      0.298651
# 4      0.272631

# %%
x_test_df.head()
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0          0.686275    0.064243       0.058586    0.020575    0.062094
# 1          0.705882    0.038015       0.026869    0.010035    0.029369
# 2          0.901961    0.044846       0.052929    0.033217    0.054122
# 3          0.313725    0.059996       0.059798    0.026154    0.061045
# 4          0.411765    0.122929       0.090101    0.034871    0.091882
#
#    medianIncome
# 0      0.353133
# 1      0.770182
# 2      0.133626
# 3      0.263576
# 4      0.660046

# %% [markdown]
# ### Create Feature Columns
#
# ** Create the necessary tf.feature_column objects for the estimator. They should all be trated as continuous numeric_columns. **

# %%
house_age=tf.feature_column.numeric_column('housingMedianAge')
total_rm=tf.feature_column.numeric_column('totalRooms')
bedrm=tf.feature_column.numeric_column('totalBedrooms')
pop=tf.feature_column.numeric_column('population')
hshold=tf.feature_column.numeric_column('households')
income=tf.feature_column.numeric_column('medianIncome')

# %%
feat_cols=[house_age,total_rm,bedrm, pop,hshold, income]

# %% [markdown]
# ** Create the input function for the estimator object. (play around with batch_size and num_epochs)**

# %%
input_func=tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10, num_epochs=1000,shuffle=True)

# %% [markdown]
# ** Create the estimator model. Use a DNNRegressor. Play around with the hidden units! **

# %%
dnn_model=tf.estimator.DNNRegressor(hidden_units=[6,6,6],feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Raymond\AppData\Local\Temp\tmposu970f1
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Raymond\\AppData\\Local\\Temp\\tmposu970f1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %% [markdown]
# ##### ** Train the model for ~1,000 steps. (Later come back to this and train it for more and check for improvement) **

# %%
dnn_model.train(input_fn=input_func,steps=1500)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Raymond\AppData\Local\Temp\tmposu970f1\model.ckpt.
# INFO:tensorflow:loss = 561166800000.0, step = 1
# INFO:tensorflow:global_step/sec: 267.743
# INFO:tensorflow:loss = 131579650000.0, step = 101 (0.375 sec)
# INFO:tensorflow:global_step/sec: 422.099
# INFO:tensorflow:loss = 260490130000.0, step = 201 (0.237 sec)
# INFO:tensorflow:global_step/sec: 459.591
# INFO:tensorflow:loss = 80984870000.0, step = 301 (0.218 sec)
# INFO:tensorflow:global_step/sec: 418.899
# INFO:tensorflow:loss = 1051282240000.0, step = 401 (0.239 sec)
# INFO:tensorflow:global_step/sec: 415.732
# INFO:tensorflow:loss = 242645700000.0, step = 501 (0.241 sec)
# INFO:tensorflow:global_step/sec: 443.313
# ...

# %% [markdown]
# ** Create a prediction input function and then use the .predict method off your estimator model to create a list or predictions on your test data. **

# %%
pred_input_fn=tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
pred_gen=model.predict(pred_input_fn)
predictions=list(pred_gen)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Raymond\AppData\Local\Temp\tmpuerj96d1\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# [{'predictions': array([81338.375], dtype=float32)},
#  {'predictions': array([47153.15], dtype=float32)},
#  {'predictions': array([75004.06], dtype=float32)},
#  {'predictions': array([80645.63], dtype=float32)},
#  {'predictions': array([143464.66], dtype=float32)},
#  {'predictions': array([187973.7], dtype=float32)},
#  {'predictions': array([108743.69], dtype=float32)},
#  {'predictions': array([101235.65], dtype=float32)},
#  {'predictions': array([102987.4], dtype=float32)},
#  {'predictions': array([4825.662], dtype=float32)},
#  {'predictions': array([124520.68], dtype=float32)},
#  {'predictions': array([265843.], dtype=float32)},
#  {'predictions': array([86874.64], dtype=float32)},
#  {'predictions': array([53416.324], dtype=float32)},
#  {'predictions': array([104765.836], dtype=float32)},
#  {'predictions': array([35211.9], dtype=float32)},
#  {'predictions': array([40169.133], dtype=float32)},
#  {'predictions': array([111960.58], dtype=float32)},
# ...

# %% [markdown]
# ** Calculate the RMSE. You should be able to get around 100,000 RMSE (remember that this is in the same units as the label.) Do this manually or use [sklearn.metrics](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html) **

# %%
>>> from sklearn.metrics import mean_squared_error

# %%
final_prediction=[]
for p in predictions:
    final_prediction.append(p['predictions'])

# %%
>>> mean_squared_error(y_test, final_prediction)**0.5
# Out:
# 163586.54885313511
